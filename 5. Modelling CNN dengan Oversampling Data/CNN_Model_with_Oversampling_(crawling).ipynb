# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %% [markdown]
# #### download dataset which have same categories images

# %%
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/modul 3"

# %%
# %cd /content/drive/MyDrive/Praktikum Kelompok/Dataset
# Out:
# /content/drive/MyDrive/Praktikum Kelompok/Dataset

# %%
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# ...
# 100% 2.29G/2.29G [00:29<00:00, 35.7MB/s]
# 100% 2.29G/2.29G [00:29<00:00, 84.5MB/s]

# %%
# !kaggle datasets download -d pranavraikokte/covid19-image-dataset
# Out:
# ...
#  99% 157M/158M [00:03<00:00, 58.5MB/s]
# 100% 158M/158M [00:03<00:00, 46.0MB/s]

# %%
# !ls -a
# Out:
# chest_xray		  Covid19-dataset	     splitted_dataset
# chest-xray-pneumonia.zip  covid19-image-dataset.zip

# %%
import zipfile

# %%
# Ekstrak dataset
local_zip = "/content/drive/MyDrive/Praktikum Kelompok/Dataset/chest-xray-pneumonia.zip"
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content/drive/MyDrive/Praktikum Kelompok/Dataset')
zip_ref.close()

# %%
# Ekstrak dataset
local_zip = "/content/drive/MyDrive/Praktikum Kelompok/Dataset/covid19-image-dataset.zip"
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content/drive/MyDrive/Praktikum Kelompok/Dataset')
zip_ref.close()

# %%
import shutil
from shutil import copytree
shutil.copytree("/content/drive/MyDrive/splitted 2", "/content/drive/MyDrive/Praktikum Kelompok/Dataset/splitted_dataset")
# Out:
# '/content/drive/MyDrive/Praktikum Kelompok/Dataset/splitted_dataset'

# %% [markdown]
# #### adding dataset from other sources to our dataset folder (train only)

# %%
#train_dir = '/content/drive/MyDrive/Praktikum Kelompok/Dataset/Covid19-dataset'
cov_train_dir = '/content/drive/MyDrive/Praktikum Kelompok/Dataset/splitted_dataset/train/covid'
nof_train_dir = '/content/drive/MyDrive/Praktikum Kelompok/Dataset/splitted_dataset/train/No_findings'
nor_train_dir = '/content/drive/MyDrive/Praktikum Kelompok/Dataset/splitted_dataset/train/normal'
bac_train_dir = '/content/drive/MyDrive/Praktikum Kelompok/Dataset/splitted_dataset/train/pneumonia_bacterial'
vir_train_dir = '/content/drive/MyDrive/Praktikum Kelompok/Dataset/splitted_dataset/train/pneumonia_viral'

#test_dir = '/content/drive/MyDrive/Praktikum Kelompok/Dataset/Covid19-dataset/test'
#cov_test_dir = test_dir + '/Covid'
#vir_test_dir = test_dir + '/Normal'
#pne_test_dir = test_dir + '/Viral Pneumonia'

# %%
print("Total Training covid               :", len(os.listdir(cov_train_dir)))
print("Total Training no funding          :", len(os.listdir(nof_train_dir)))
print("Total Training normal              :", len(os.listdir(nor_train_dir)))
print("Total Training pneumonia bacterial :", len(os.listdir(bac_train_dir)))
print("Total Training pneumonia viral     :", len(os.listdir(vir_train_dir)))
# Out:
# Total Training covid               : 400
# Total Training no funding          : 400
# Total Training normal              : 400
# Total Training pneumonia bacterial : 400
# Total Training pneumonia viral     : 400

# %% [markdown]
# #### augmentasi process

# %%
train_dir = '/content/drive/MyDrive/Praktikum Kelompok/Dataset/splitted_dataset/train'
val_dir = '/content/drive/MyDrive/Praktikum Kelompok/Dataset/splitted_dataset/val'
test_dir = '/content/drive/MyDrive/Praktikum Kelompok/Dataset/splitted_dataset/test'

# %%
nof_train_dir = train_dir + '/No_findings'
cov_train_dir = train_dir + '/covid'
nor_train_dir = train_dir + '/normal'
bac_train_dir = train_dir + '/pneumonia_bacterial'
vir_train_dir = train_dir + '/pneumonia_viral'

nof_val_dir = val_dir + '/No_findings'
cov_val_dir = val_dir + '/covid'
nor_val_dir = val_dir + '/normal'
bac_val_dir = val_dir + '/pneumonia_bacterial'
vir_val_dir = val_dir + '/pneumonia_viral'

nof_test_dir = test_dir + '/No_findings'
cov_test_dir = test_dir + '/covid'
nor_test_dir = test_dir + '/normal'
bac_test_dir = test_dir + '/pneumonia_bacterial'
vir_test_dir = test_dir + '/pneumonia_viral'

print('Jumlah Train No FIndings :', len(os.listdir(nof_train_dir)))
print('Jumlah Train Covid       :', len(os.listdir(cov_train_dir)))
print('Jumlah Train Normal      :', len(os.listdir(nor_train_dir)))
print('Jumlah Train Bacterial   :', len(os.listdir(bac_train_dir)))
print('Jumlah Train Viral       :', len(os.listdir(vir_train_dir)))
print()
print('Jumlah Validation No FIndings :', len(os.listdir(nof_val_dir)))
print('Jumlah Validation Covid       :', len(os.listdir(cov_val_dir)))
print('Jumlah Validation Normal      :', len(os.listdir(nor_val_dir)))
print('Jumlah Validation Bacterial   :', len(os.listdir(bac_val_dir)))
print('Jumlah Validation Viral       :', len(os.listdir(vir_val_dir)))
print()
print('Jumlah Test No FIndings :', len(os.listdir(nof_test_dir)))
print('Jumlah Test Covid       :', len(os.listdir(cov_test_dir)))
print('Jumlah Test Normal      :', len(os.listdir(nor_test_dir)))
print('Jumlah Test Bacterial   :', len(os.listdir(bac_test_dir)))
print('Jumlah Test Viral       :', len(os.listdir(vir_test_dir)))
# Out:
# Jumlah Train No FIndings : 400
# Jumlah Train Covid       : 400
# Jumlah Train Normal      : 400
# Jumlah Train Bacterial   : 400
# Jumlah Train Viral       : 400
#
# Jumlah Validation No FIndings : 95
# Jumlah Validation Covid       : 60
# Jumlah Validation Normal      : 84
# Jumlah Validation Bacterial   : 85
# Jumlah Validation Viral       : 80
#
# Jumlah Test No FIndings : 5
# Jumlah Test Covid       : 4
# Jumlah Test Normal      : 5
# Jumlah Test Bacterial   : 5
# Jumlah Test Viral       : 5

# %%
import matplotlib.pyplot as plt 
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from keras.callbacks import ReduceLROnPlateau

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    horizontal_flip=True,
    vertical_flip=True,
    shear_range=0.5,
    fill_mode='nearest',
)
test_datagen = ImageDataGenerator(rescale=1./255)
#datagen = ImageDataGenerator(rescale=0)

train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=(250,250),
    color_mode="rgb",
    shuffle=True,
    class_mode='categorical'
)

val_gen = train_datagen.flow_from_directory(
    val_dir,
    target_size=(250,250),
    color_mode="rgb",
    shuffle=False,
    class_mode='categorical'
)

test_gen = test_datagen.flow_from_directory(
    test_dir,
    target_size=(250,250),
    color_mode="rgb",
    shuffle=False,
    class_mode='categorical'
)
# Out:
# Found 2000 images belonging to 5 classes.
# Found 404 images belonging to 5 classes.
# Found 24 images belonging to 5 classes.

# %% [markdown]
# #### build model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Conv2D, MaxPool2D, MaxPooling2D, Flatten, BatchNormalization, Dropout

from tensorflow.keras.optimizers import Adam

# %%
DESIRED_ACCURACY = 0.87

class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epochs, logs={}) :
        if(logs.get('val_acc') is not None and logs.get('val_acc') >= DESIRED_ACCURACY) :
            print('\nReached 95% accuracy so cancelling training!')
            self.model.stop_training = True

callbacks = myCallback()

# %%
model = Sequential()

model.add(InputLayer(input_shape=[250,250,3]))

model.add(Conv2D(16, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(16, (3,3), activation = 'relu'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(16, (3,3), activation = 'relu'))
model.add(MaxPooling2D(2,2))

model.add(BatchNormalization())
model.add(Flatten())

model.add(Dense(units=512, activation='relu'))
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=5, activation='softmax'))

print(model.summary())

model.compile(optimizer=Adam(learning_rate = 0.001),
              loss='categorical_crossentropy',
              metrics=['acc']
              )
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 248, 248, 16)      448
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 124, 124, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 122, 122, 16)      2320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 61, 61, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 59, 59, 16)        2320
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 29, 29, 16)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 29, 29, 16)        64
# ...

# %%
train_step_size = train_gen.n//train_gen.batch_size
val_step_size = val_gen.n//val_gen.batch_size

print(train_step_size)
print(val_step_size)
# Out:
# 62
# 12

# %%
history = model.fit(train_gen,
              epochs=100,
              steps_per_epoch=train_step_size,
              validation_data=val_gen,
              validation_steps=val_step_size,
              callbacks=callbacks,
              verbose=2,
              )
# Out:
# Epoch 1/100
# 62/62 - 1737s - loss: 1.1926 - acc: 0.6433 - val_loss: 8.3524 - val_acc: 0.3646
# Epoch 2/100
# 62/62 - 121s - loss: 0.5393 - acc: 0.8120 - val_loss: 1.9225 - val_acc: 0.6042
# Epoch 3/100
# 62/62 - 121s - loss: 0.4095 - acc: 0.8562 - val_loss: 3.5645 - val_acc: 0.4661
# Epoch 4/100
# 62/62 - 121s - loss: 0.3202 - acc: 0.8867 - val_loss: 1.5457 - val_acc: 0.7370
# Epoch 5/100
# 62/62 - 124s - loss: 0.2601 - acc: 0.9106 - val_loss: 4.1130 - val_acc: 0.5104
# Epoch 6/100
# 62/62 - 122s - loss: 0.2015 - acc: 0.9309 - val_loss: 1.2420 - val_acc: 0.6562
# Epoch 7/100
# 62/62 - 122s - loss: 0.1656 - acc: 0.9451 - val_loss: 6.0101 - val_acc: 0.3438
# Epoch 8/100
# 62/62 - 122s - loss: 0.2146 - acc: 0.9411 - val_loss: 1.9777 - val_acc: 0.5677
# Epoch 9/100
# 62/62 - 124s - loss: 0.1104 - acc: 0.9665 - val_loss: 0.7666 - val_acc: 0.8307
# Epoch 10/100
# 62/62 - 121s - loss: 0.0594 - acc: 0.9827 - val_loss: 0.7112 - val_acc: 0.8411
# Epoch 11/100
# ...

# %% [markdown]
# #### save model

# %%
import json

target_dir = '/content/drive/MyDrive/Praktikum Kelompok/model'

# simpan history model pertama
history_dict = history.history
json.dump(history_dict, open(target_dir + '/history_model_cnn_2.json', 'w'))

# simpan model pertama dan weight-nya
model.save(target_dir + '/model_cnn_2.h5')
model.save_weights(target_dir + '/weight_model_cnn_2.hdf5')

# %% [markdown]
# #### evaluasi

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import metrics
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.models import Sequential, load_model
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# %%
import json
target_dir = '/content/drive/MyDrive/Praktikum Kelompok/model/'
history = json.load(open(target_dir + '/history_model_cnn_2.json', 'r'))

# %%
plt.figure(figsize = (20,8))
plt.xticks(fontsize='15')
plt.yticks(fontsize='15')
plt.subplot(1, 2, 1) 
plt.plot(history['acc'],     label="train_acc")
plt.plot(history['val_acc'], label="val_acc")
plt.title('Model Accuracy', fontsize=15)
plt.ylabel('accuracy', fontsize=15)
plt.xlabel('epoch', fontsize=15)
plt.legend(loc='upper left', fontsize=15)
#plt.show()

#plt.figure(figsize = (10,8))
plt.xticks(fontsize='15')
plt.yticks(fontsize='15')
plt.subplot(1, 2, 2) 
plt.plot(history['loss'],    label="train_loss")
plt.plot(history['val_loss'], label="val_loss)")
plt.title('Model Loss', fontsize=15)
plt.ylabel('loss', fontsize=15)
plt.xlabel('epoch', fontsize=15)
plt.legend(loc='upper left', fontsize=15)
plt.show()

# %%
from keras.models import load_model

# load model pertama
target_dir = '/content/drive/MyDrive/Praktikum Kelompok/model/'
model_saved = load_model(target_dir + '/model_cnn_2.h5')

# %%
test_score = model_saved.evaluate_generator(test_gen, test_gen.batch_size)
print("[INFO] accuracy: {:.2f}%".format(test_score[1] * 100)) 
print("[INFO] Loss: ",test_score[0])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2006: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 32 batches). You may need to use the repeat() function when building your dataset.
# [INFO] accuracy: 100.00%
# [INFO] Loss:  0.024938412010669708

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np

# %%
#Print Classification Report
#Print the Target names

target_names = []

for key in train_gen.class_indices:
    target_names.append(key)

Y_pred = model_saved.predict_generator(test_gen)
y_pred = np.argmax(Y_pred, axis=1)

print('Classification Report')
print(classification_report(test_gen.classes, y_pred, target_names=target_names))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# Classification Report
#                      precision    recall  f1-score   support
#
#         No_findings       1.00      1.00      1.00         5
#               covid       1.00      1.00      1.00         4
#              normal       1.00      1.00      1.00         5
# pneumonia_bacterial       1.00      1.00      1.00         5
#     pneumonia_viral       1.00      1.00      1.00         5
#
#            accuracy                           1.00        24
#           macro avg       1.00      1.00      1.00        24
#        weighted avg       1.00      1.00      1.00        24

# %%
from sklearn import metrics
Cmatrix_test = confusion_matrix(test_gen.classes, y_pred)
class_names = test_gen.class_indices

plt.figure(figsize = (16,12))
ax = plt.subplot()
sns.set(font_scale=2.0) # Adjust to fit
sns.heatmap(Cmatrix_test,annot=True, fmt='',ax=ax, cmap=plt.cm.Reds)

# labels, title and ticks
label_font = {'size':'15'}  # Adjust to fit
ax.set_xlabel('Predicted labels', fontdict=label_font)
ax.set_ylabel('True labels', fontdict=label_font) 

title_font = {'size':'18'}  # Adjust to fit
ax.set_title('Confusion Matrix', fontdict=title_font)

ax.tick_params(axis='both', which='major', labelsize=15)  # Adjust to fit
ax.xaxis.set_ticklabels(class_names)   
ax.yaxis.set_ticklabels(class_names)
plt.title('Confusion Matrix Test',fontsize=14)
plt.show()

# %%
import time
def pred_img(img_path):
    img = load_img(img_path, target_size=(250,250))
    img = tf.keras.utils.img_to_array(img)
    img = np.expand_dims(img, axis=0)

    start_pred_time = time.time()

    pred_result = model_saved.predict(img)
    #print(pred_result)
    
    end_pred_time = time.time()

    pred_value = np.argmax(pred_result)
    #print(pred_value)
    #pred_label = list(label_dict.keys())[list(label_dict.values()).index(pred_value)]
    pred_label = 'No_findings' if pred_value == 0 else 'covid' if pred_value == 1 else 'normal' if pred_value == 2 else 'pneumonia_bacterial' if pred_value == 3 else 'pneumonia_viral'
    confidence_percent = np.max(pred_result) * 100
    pred_time = end_pred_time - start_pred_time

    return pred_label, confidence_percent, pred_time

# %%
nof_name_dir = [os.path.join(nof_test_dir, fname) for fname in os.listdir(nof_test_dir)[:4]]
cov_name_dir = [os.path.join(cov_test_dir, fname) for fname in os.listdir(cov_test_dir)[:4]]
nor_name_dir = [os.path.join(nor_test_dir, fname) for fname in os.listdir(nor_test_dir)[:4]]
bac_name_dir = [os.path.join(bac_test_dir, fname) for fname in os.listdir(bac_test_dir)[:4]]
vir_name_dir = [os.path.join(vir_test_dir, fname) for fname in os.listdir(vir_test_dir)[:4]]

classify_dir = nof_name_dir + cov_name_dir + nor_name_dir + bac_name_dir + vir_name_dir

# %%
import cv2

# %%
nrows = 5
ncols = 4

fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

for i, img_path in enumerate(classify_dir):
    sns.set(font_scale=0.8)
    plt.subplot(nrows, ncols, i + 1)
    plt.subplots_adjust(hspace=1.5)

    
    img = cv2.imread(img_path)
    img = cv2.resize(img, (250,250))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    true_label = img_path.split(os.path.sep)[-2]
    pred_result = pred_img(img_path)
    pred_label = pred_result[0]
    confidence_percent = pred_result[1]
    pred_time = pred_result[2]

    plt.title(f"True Label: {true_label}\nPred Label: {pred_label}\nAkurasi: {confidence_percent:.2f}%\nTime: {pred_time:.4f}s", y=1.15)
    plt.imshow(img)

plt.show()
